# %%
import pandas as pd

frequentation= pd.read_csv("../../frequentation.csv")
objets= pd.read_csv("../../objets_trouves.csv")
meteo= pd.read_csv("../../all_meteo.csv")

# %%
with open('fichier_concat_good1.csv', 'r') as file:
    lines = file.readlines()

# Enlever les guillemets de chaque ligne
for i in range(len(lines)):
    lines[i] = lines[i].replace('"', '')

# Écrire les lignes modifiées dans un nouveau fichier
with open('fichier_concat_good1.csv', 'w') as file:
    file.writelines(lines)

# %%
new_df = df.loc[:, ['DATE', 'PRECIP_TOTAL_DAY_MM', 'CLOUDCOVER_AVG_PERCENT', 'SUNHOUR', 'VISIBILITY_AVG_KM']]

# Afficher les premières lignes du nouveau DataFrame pour vérification
print(new_df.head())
# Out:
#          DATE  PRECIP_TOTAL_DAY_MM  CLOUDCOVER_AVG_PERCENT  SUNHOUR  \
# 0  2021-11-01                  0.2                  40.875      7.0
# 1  2021-11-02                  0.7                  94.375      3.7
# 2  2021-11-03                  0.0                  10.750      8.7
# 3  2021-11-04                  0.3                  48.125      5.4
# 4  2021-11-05                  0.0                  60.625      8.7
#
#    VISIBILITY_AVG_KM
# 0               10.0
# 1               10.0
# 2               10.0
# 3               10.0
# 4               10.0

# %% [markdown]
# # arrondir valeures

# %%
new_data = []

# Itérer sur les lignes du DataFrame original
for index, row in df.iterrows():
    # Extraire la première colonne (DATE)
    date_value = row['DATE']
    
    # Arrondir les valeurs des trois dernières colonnes
    precip_rounded = round(row['PRECIP_TOTAL_DAY_MM'])
    cloudcover_rounded = round(row['CLOUDCOVER_AVG_PERCENT'])
    sunhour_rounded = round(row['SUNHOUR'])
    visibility_rounded = round(row['VISIBILITY_AVG_KM'])
    
    # Ajouter les valeurs arrondies et la date à la nouvelle ligne de données
    new_row = [date_value, precip_rounded, cloudcover_rounded, sunhour_rounded, visibility_rounded]
    
    # Ajouter la nouvelle ligne au DataFrame
    new_data.append(new_row)

# Créer un nouveau DataFrame avec les données arrondies
new_df = pd.DataFrame(new_data, columns=['DATE', 'PRECIP_TOTAL_DAY_MM', 'CLOUDCOVER_AVG_PERCENT', 'SUNHOUR', 'VISIBILITY_AVG_KM'])

# Afficher les premières lignes du nouveau DataFrame pour vérification

dfg= new_df[['DATE', 'CLOUDCOVER_AVG_PERCENT', 'SUNHOUR']]
print(dfg.head(2000))
# Out:
#             DATE  CLOUDCOVER_AVG_PERCENT  SUNHOUR
# 0     2021-11-01                      41        7
# 1     2021-11-02                      94        4
# 2     2021-11-03                      11        9
# 3     2021-11-04                      48        5
# 4     2021-11-05                      61        9
# ...          ...                     ...      ...
# 1120  2023-08-27                      46        9
# 1121  2023-08-28                      48       10
# 1122  2023-08-29                      34        9
# 1123  2023-08-30                      45        9
# 1124  2023-08-31                      66        7
#
# [1125 rows x 3 columns]

# %%
dfg.columns
# Out:
# Index(['DATE', 'CLOUDCOVER_AVG_PERCENT', 'SUNHOUR'], dtype='object')

# %%
dfg.to_csv('dfg.csv', index=False)

# %%
dfg = dfg.drop_duplicates()

# %%
import sqlite3


dif = pd.read_csv('frequentation.csv')

conn = sqlite3.connect('bddt.db')
curseur = conn.cursor()

for index, row in dfg.iterrows():
    curseur.execute("INSERT INTO lumiere (date, cloud, sun) VALUES (?, ?, ?)", (row['DATE'], row['CLOUDCOVER_AVG_PERCENT'], (row['SUNHOUR'])))
conn.commit()   
# for index, row in dif.iterrows():
#     curseur.execute("INSERT INTO gare (nom_gare, frequent_2019,frequent_2020,frequent_2021,frequent_2022) VALUES (?, ?,?,?,?)", (row['gare'], row['frequent_2019'],row['frequent_2020'],row['frequent_2021'],row['frequent_2022']))
# conn.commit()    

# for index, row in daf.iterrows():
#     curseur.execute("INSERT INTO objets_trouves (data,typo,gare) VALUES (?, ?,?)", (row['data'], row['typo'],row['gare']))
conn.commit()    

conn.close()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# /home/utilisateur/Documents/all_projects/rendu_sncf/lost_translation_sncf/operation_good_concat.ipynb Cell 8 line 1
#       <a href='vscode-notebook-cell:/home/utilisateur/Documents/all_projects/rendu_sncf/lost_translation_sncf/operation_good_concat.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a> curseur = conn.cursor()
#       <a href='vscode-notebook-cell:/home/utilisateur/Documents/all_projects/rendu_sncf/lost_translation_sncf/operation_good_concat.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> for index, row in dfg.iterrows():
# ---> <a href='vscode-notebook-cell:/home/utilisateur/Documents/all_projects/rendu_sncf/lost_translation_sncf/operation_good_concat.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a>     curseur.execute("INSERT INTO lumiere (date, cloud, sun) VALUES (?, ?, ?)", (row['DATE'], row['CLOUDCOVER_AVG_PERCENT'], (row['SUNHOUR'])))
#      <a href='vscode-notebook-cell:/home/utilisateur/Documents/all_projects/rendu_sncf/lost_translation_sncf/operation_good_concat.ipynb#X10sZmlsZQ%3D%3D?line=10'>11</a> conn.commit()
#      <a href='vscode-notebook-cell:/home/utilisateur/Documents/all_projects/rendu_sncf/lost_translation_sncf/operation_good_concat.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a> # for index, row in dif.iterrows():
#      <a href='vscode-notebook-cell:/home/utilisateur/Documents/all_projects/rendu_sncf/lost_translation_sncf/operation_good_concat.ipynb#X10sZmlsZQ%3D%3D?line=12'>13</a> #     curseur.execute("INSERT INTO gare (nom_gare, frequent_2019,frequent_2020,frequent_2021,frequent_2022) VALUES (?, ?,?,?,?)", (row['gare'], row['frequent_2019'],row['frequent_2020'],row['frequent_2021'],row['frequent_2022']))
#      <a href='vscode-notebook-cell:/home/utilisateur/Documents/all_projects/rendu_sncf/lost_translation_sncf/operation_good_concat.ipynb#X10sZmlsZQ%3D%3D?line=13'>14</a> # conn.commit()
#      <a href='vscode-notebook-cell:/home/utilisateur/Documents/all_projects/rendu_sncf/lost_translation_sncf/operation_good_concat.ipynb#X10sZmlsZQ%3D%3D?line=14'>15</a>
#      <a href='vscode-notebook-cell:/home/utilisateur/Documents/all_projects/rendu_sncf/lost_translation_sncf/operation_good_concat.ipynb#X10sZmlsZQ%3D%3D?line=15'>16</a> # for index, row in daf.iterrows():
#      <a href='vscode-notebook-cell:/home/utilisateur/Documents/all_projects/rendu_sncf/lost_translation_sncf/operation_good_concat.ipynb#X10sZmlsZQ%3D%3D?line=16'>17</a> #     curseur.execute("INSERT INTO objets_trouves (data,typo,gare) VALUES (?, ?,?)", (row['data'], row['typo'],row['gare']))
#
# IntegrityError: UNIQUE constraint failed: lumiere.date

# %% [markdown]
# # garder 10 premiers caractéres des lignes date

# %%
conn = sqlite3.connect('bddG.db')
cursor = conn.cursor()

# Sélection des données de la table dfg
cursor.execute("SELECT data FROM objets_trouves")
rows = cursor.fetchall()

# Mise à jour des données avec les 10 premiers caractères
updated_data = [(data[:10],) for (data,) in rows]

# Mise à jour de la table dfg avec les nouvelles données
cursor.executemany("UPDATE objets_trouves SET data = ?", updated_data)

# Validation des changements
conn.commit()

# Fermeture de la connexion
conn.close()

# %%
import pandas as pd

# Lire le fichier CSV
df = pd.read_csv('fichier_concat_good.csv')

# Afficher les noms des colonnes
print("Colonnes du fichier CSV:")
print(df.columns)
# Out:
# Colonnes du fichier CSV:
# Index(['DATE,MAX_TEMPERATURE_C,MIN_TEMPERATURE_C,WINDSPEED_MAX_KMH,TEMPERATURE_MORNING_C,TEMPERATURE_NOON_C,TEMPERATURE_EVENING_C,PRECIP_TOTAL_DAY_MM,HUMIDITY_MAX_PERCENT,VISIBILITY_AVG_KM,PRESSURE_MAX_MB,CLOUDCOVER_AVG_PERCENT,HEATINDEX_MAX_C,DEWPOINT_MAX_C,WINDTEMP_MAX_C,WEATHER_CODE_MORNING,WEATHER_CODE_NOON,WEATHER_CODE_EVENING,TOTAL_SNOW_MM,UV_INDEX,SUNHOUR,OPINION,SUNSET,SUNRISE,TEMPERATURE_NIGHT_C'], dtype='object')

# %% [markdown]
# # tri alphabetique

# %%
import pandas as pd

# Charger le fichier CSV
file_path = 'fichier_concat_good_actu.csv'

df = pd.read_csv(file_path)
print(df.columns)
# Afficher les premières lignes pour vérifier les données
print("Avant le tri:")
print(df.head())

# Trier le DataFrame par la colonne de dates en utilisant les dates comme chaînes de caractères
df_sorted = df.sort_values(by='DATE')

# Enregistrer le DataFrame trié dans un nouveau fichier CSV
output_path = 'fichier_concat_good_actu4.csv'
df_sorted.to_csv(output_path, index=False)

# Afficher les premières lignes du DataFrame trié
print("Après le tri:")
print(df_sorted.head())
# Out:
# Index(['DATE,MAX_TEMPERATURE_C,MIN_TEMPERATURE_C,WINDSPEED_MAX_KMH,TEMPERATURE_MORNING_C,TEMPERATURE_NOON_C,TEMPERATURE_EVENING_C,PRECIP_TOTAL_DAY_MM,HUMIDITY_MAX_PERCENT,VISIBILITY_AVG_KM,PRESSURE_MAX_MB,CLOUDCOVER_AVG_PERCENT,HEATINDEX_MAX_C,DEWPOINT_MAX_C,WINDTEMP_MAX_C,WEATHER_CODE_MORNING,WEATHER_CODE_NOON,WEATHER_CODE_EVENING,TOTAL_SNOW_MM,UV_INDEX,SUNHOUR,OPINION,SUNSET,SUNRISE,TEMPERATURE_NIGHT_C'], dtype='object')
# Avant le tri:
#   DATE,MAX_TEMPERATURE_C,MIN_TEMPERATURE_C,WINDSPEED_MAX_KMH,TEMPERATURE_MORNING_C,TEMPERATURE_NOON_C,TEMPERATURE_EVENING_C,PRECIP_TOTAL_DAY_MM,HUMIDITY_MAX_PERCENT,VISIBILITY_AVG_KM,PRESSURE_MAX_MB,CLOUDCOVER_AVG_PERCENT,HEATINDEX_MAX_C,DEWPOINT_MAX_C,WINDTEMP_MAX_C,WEATHER_CODE_MORNING,WEATHER_CODE_NOON,WEATHER_CODE_EVENING,TOTAL_SNOW_MM,UV_INDEX,SUNHOUR,OPINION,SUNSET,SUNRISE,TEMPERATURE_NIGHT_C
# 0  2021-11-01,15,10,23,11,14,12,0.2,76,10,1005,40...
# 1  2021-11-02,12,10,22,10,12,10,0.7,84,10,1003,94...
# 2  2021-11-03,14,7,4,7,12,12,0,79,10,1007,10.75,1...
# 3  2021-11-04,12,6,19,6,11,10,0.3,82,10,1019,48.1...
# 4  2021-11-05,12,7,11,8,11,11,0,78,10,1029,60.625...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_6902/2514206105.py in ?()
#       9 print("Avant le tri:")
#      10 print(df.head())
#      11
#      12 # Trier le DataFrame par la colonne de dates en utilisant les dates comme chaînes de caractères
# ---> 13 df_sorted = df.sort_values(by='DATE')
#      14
#      15 # Enregistrer le DataFrame trié dans un nouveau fichier CSV
#      16 output_path = 'fichier_concat_good_actu4.csv'
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'DATE'

# %% [markdown]
# # format date

# %%
import pandas as pd

# Charger le fichier CSV
file_path = 'fichier_concat_good_actu.csv'
df = pd.read_csv(file_path)

# Afficher les premières lignes pour vérifier les données
print(df.head())

# Convertir la colonne de dates en datetime avec le format spécifique
df['date_column'] = pd.to_datetime(df['DATE'], format='%Y-%d-%m')

# Trier le DataFrame par la colonne de dates
df_sorted = df.sort_values(by='date_column')

# Enregistrer le DataFrame trié dans un nouveau fichier CSV
output_path = 'fichier_concat_good_actu4.csv'
df_sorted.to_csv(output_path, index=False)

# Afficher les premières lignes du DataFrame trié
print(df_sorted.head())
# Out:
#   DATE,MAX_TEMPERATURE_C,MIN_TEMPERATURE_C,WINDSPEED_MAX_KMH,TEMPERATURE_MORNING_C,TEMPERATURE_NOON_C,TEMPERATURE_EVENING_C,PRECIP_TOTAL_DAY_MM,HUMIDITY_MAX_PERCENT,VISIBILITY_AVG_KM,PRESSURE_MAX_MB,CLOUDCOVER_AVG_PERCENT,HEATINDEX_MAX_C,DEWPOINT_MAX_C,WINDTEMP_MAX_C,WEATHER_CODE_MORNING,WEATHER_CODE_NOON,WEATHER_CODE_EVENING,TOTAL_SNOW_MM,UV_INDEX,SUNHOUR,OPINION,SUNSET,SUNRISE,TEMPERATURE_NIGHT_C
# 0  2021-11-01,15,10,23,11,14,12,0.2,76,10,1005,40...
# 1  2021-11-02,12,10,22,10,12,10,0.7,84,10,1003,94...
# 2  2021-11-03,14,7,4,7,12,12,0,79,10,1007,10.75,1...
# 3  2021-11-04,12,6,19,6,11,10,0.3,82,10,1019,48.1...
# 4  2021-11-05,12,7,11,8,11,11,0,78,10,1029,60.625...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DATE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/utilisateur/Documents/all_projects/rendu_sncf/lost_translation_sncf/operation_good_concat.ipynb Cell 14 line 1
#       <a href='vscode-notebook-cell:/home/utilisateur/Documents/all_projects/rendu_sncf/lost_translation_sncf/operation_good_concat.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a> print(df.head())
#      <a href='vscode-notebook-cell:/home/utilisateur/Documents/all_projects/rendu_sncf/lost_translation_sncf/operation_good_concat.ipynb#X20sZmlsZQ%3D%3D?line=9'>10</a> # Convertir la colonne de dates en datetime avec le format spécifique
# ---> <a href='vscode-notebook-cell:/home/utilisateur/Documents/all_projects/rendu_sncf/lost_translation_sncf/operation_good_concat.ipynb#X20sZmlsZQ%3D%3D?line=10'>11</a> df['date_column'] = pd.to_datetime(df['DATE'], format='%Y-%d-%m')
#      <a href='vscode-notebook-cell:/home/utilisateur/Documents/all_projects/rendu_sncf/lost_translation_sncf/operation_good_concat.ipynb#X20sZmlsZQ%3D%3D?line=12'>13</a> # Trier le DataFrame par la colonne de dates
#      <a href='vscode-notebook-cell:/home/utilisateur/Documents/all_projects/rendu_sncf/lost_translation_sncf/operation_good_concat.ipynb#X20sZmlsZQ%3D%3D?line=13'>14</a> df_sorted = df.sort_values(by='date_column')
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'DATE'

# %%
file_path = 'fichier_concat_good_actu.csv'
df = pd.read_csv(file_path)
df.columns
# Out:
# Index(['DATE,MAX_TEMPERATURE_C,MIN_TEMPERATURE_C,WINDSPEED_MAX_KMH,TEMPERATURE_MORNING_C,TEMPERATURE_NOON_C,TEMPERATURE_EVENING_C,PRECIP_TOTAL_DAY_MM,HUMIDITY_MAX_PERCENT,VISIBILITY_AVG_KM,PRESSURE_MAX_MB,CLOUDCOVER_AVG_PERCENT,HEATINDEX_MAX_C,DEWPOINT_MAX_C,WINDTEMP_MAX_C,WEATHER_CODE_MORNING,WEATHER_CODE_NOON,WEATHER_CODE_EVENING,TOTAL_SNOW_MM,UV_INDEX,SUNHOUR,OPINION,SUNSET,SUNRISE,TEMPERATURE_NIGHT_C'], dtype='object')

# %%
import pandas as pd
import sqlite3

# Charger le fichier CSV
df = pd.read_csv("fichier_concat_good_actu.csv")

# Afficher les colonnes pour vérifier les noms
print("Colonnes du DataFrame :")
print(df.columns)

# Connexion à la base de données SQLite
conn = sqlite3.connect('bdd_luz.db')
curseur = conn.cursor()

# Itérer sur les lignes du DataFrame et insérer dans la base de données
n = 1
for index, row in df.iterrows():
    try:
        curseur.execute(
            "INSERT INTO lumiere (DATE, cloud, sun) VALUES (?, ?, ?)",
            (row['DATE'], row['CLOUDCOVER_AVG_PERCENT'], row['SUNHOUR'])
        )
        print(f"Inséré ligne {n}")
        n += 1
    except KeyError as e:
        print(f"Erreur de clé : {e}")

# Valider les changements et fermer la connexion
conn.commit()
conn.close()
# Out:
# Colonnes du DataFrame :
# Index(['DATE,MAX_TEMPERATURE_C,MIN_TEMPERATURE_C,WINDSPEED_MAX_KMH,TEMPERATURE_MORNING_C,TEMPERATURE_NOON_C,TEMPERATURE_EVENING_C,PRECIP_TOTAL_DAY_MM,HUMIDITY_MAX_PERCENT,VISIBILITY_AVG_KM,PRESSURE_MAX_MB,CLOUDCOVER_AVG_PERCENT,HEATINDEX_MAX_C,DEWPOINT_MAX_C,WINDTEMP_MAX_C,WEATHER_CODE_MORNING,WEATHER_CODE_NOON,WEATHER_CODE_EVENING,TOTAL_SNOW_MM,UV_INDEX,SUNHOUR,OPINION,SUNSET,SUNRISE,TEMPERATURE_NIGHT_C'], dtype='object')
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
# Erreur de clé : 'DATE'
